# %% [markdown]
# # TASK - 4 PREDICTION USING DECISION TREE ALGORITHM

# %% [markdown]
# For the given ‘Iris’ dataset, create the Decision Tree classifier and visualize it
# graphically.
# The purpose is if we feed any new data to this classifier, it would be able to
# predict the right class accordingly.
# DATASET- https://bit.ly/3kXTdox

# %% [markdown]
# # IMPORT LIBRARY

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # LOAD THE IRIS DATA

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# # PRINT THE LAST FIVE ROWS

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# # PRINT THE RANDOM EIGHT ROW

# %%
iris.sample(8)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 87            6.3          2.3           4.4          1.3  versicolor
# 69            5.6          2.5           3.9          1.1  versicolor
# 48            5.3          3.7           1.5          0.2      setosa
# 132           6.4          2.8           5.6          2.2   virginica
# 84            5.4          3.0           4.5          1.5  versicolor
# 54            6.5          2.8           4.6          1.5  versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 65            6.7          3.1           4.4          1.4  versicolor

# %% [markdown]
# # PROPERTIES AND SHAPE OF THE DATASET

# %%
print(iris.info())             #full summary of the dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB
# None

# %%
print(iris.describe())    #statistical details of the dataset
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
print(iris.shape)      #shape of dataset
# Out:
# (150, 5)

# %% [markdown]
# # CHECK THE DATA FOR ANY NULL VALUES, COUNT THE NO. OF NULL  VALUES IN EACH COLUMN

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
print("total number of null values = ",iris.isnull().sum().sum())
# Out:
# total number of null values =  0

# %% [markdown]
# # BOX PLOT

# %%
x = sns.boxplot(x="species", y="sepal_length",data=iris)

# %%
ax = sns.boxplot(x="species", y="sepal_width",data=iris)

# %%
ax = sns.boxplot(x="species", y="petal_length",data=iris)

# %% [markdown]
# # SCATTER PLOT

# %%
fig,ax = plt.subplots(figsize=(16,8))
ax.scatter(iris['sepal_length'],iris['sepal_width'])            #Plotting the distribution of scores
plt.title('sepal_length and sepal_width') 
ax.set_ylabel('sepal_length')
ax.set_xlabel('sepal_width')
plt.show()

# %%
fig,ax = plt.subplots(figsize=(16,8))
ax.scatter(iris['petal_length'],iris['petal_width'])            #Plotting the distribution of scores
plt.title('petal_length and petal_width') 
ax.set_ylabel('petal_length')
ax.set_xlabel('petal_width')
plt.show()

# %%
sns.pairplot(iris,hue="species")

# %%
sns.pairplot(iris)

# %%
iris.corr()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
plt.figure(figsize=(12,8))
sns.countplot(x='species',data=iris)

# %% [markdown]
# # HEATMAP

# %%
plt.figure(figsize=(10,4))
sns.heatmap(iris.corr(),annot=True,cmap="cubehelix_r")
plt.show()

# %% [markdown]
# # SPLITTING THE DATASET INTO TRAINING AND TESTING DATA

# %%
X=iris.drop('species',axis=1).values
Y=iris['species'].values
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,random_state = 0,test_size=0.2)

# %% [markdown]
# # FITTING USING DECISION TREE ALGORITHM

# %%
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
d_train=dtree.fit(X_train,Y_train)

# %% [markdown]
# # PREDICTION

# %%
y_pred=dtree.predict(X_test)

# %% [markdown]
# # ACCURACY SCORE

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_pred,Y_test)
# Out:
# 1.0

# %%
print("Accuracy of Decision Tree on Best Parameters",accuracy_score(Y_test,y_pred))
# Out:
# Accuracy of Decision Tree on Best Parameters 1.0

# %% [markdown]
# #  EVALUATING THE ALGORITHM

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# [[11  0  0]
#  [ 0 13  0]
#  [ 0  0  6]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        11
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00         6
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
features=['sepal_length','sepal_width','petal_length','petal_width']
targets=['iris-setosa','iris-versicolor','iris-virginica']

# %%
from sklearn.tree import plot_tree
from sklearn import tree
fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(5,5),dpi=300)
tree.plot_tree(dtree,feature_names=features,class_names=targets,filled=True)
fig.savefig(r'C:\Users\Admin\Downloads\Irispic.jpg')
plt.show(fig.savefig)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-34-a9fd681e2d51> in <module>
#       3 fig,ax=plt.subplots(nrows=1,ncols=1,figsize=(5,5),dpi=300)
#       4 tree.plot_tree(dtree,feature_names=features,class_names=targets,filled=True)
# ----> 5 fig.savefig(r'C:\Users\Admin\Downloads\Irispic.jpg')
#       6 plt.show(fig.savefig)
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in savefig(self, fname, transparent, **kwargs)
#    2201             self.patch.set_visible(frameon)
#    2202
# -> 2203         self.canvas.print_figure(fname, **kwargs)
#    2204
#    2205         if frameon:
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, **kwargs)
#    2117
#    2118             try:
# -> 2119                 result = print_method(
#    2120                     filename,
#    2121                     dpi=dpi,
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py in print_jpg(self, filename_or_obj, dryrun, pil_kwargs, *args, **kwargs)
#     597             pil_kwargs.setdefault("quality", rcParams["savefig.jpeg_quality"])
#     598             pil_kwargs.setdefault("dpi", (self.figure.dpi, self.figure.dpi))
# --> 599             return background.save(
#     600                 filename_or_obj, format='jpeg', **pil_kwargs)
#     601
#
# ~\anaconda3\lib\site-packages\PIL\Image.py in save(self, fp, format, **params)
#    2153                 fp = builtins.open(filename, "r+b")
#    2154             else:
# -> 2155                 fp = builtins.open(filename, "w+b")
#    2156
#    2157         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\Admin\\Downloads\\Irispic.jpg'

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plot_tree(dtree,rounded=True,filled=True)
plt.show()

# %% [markdown]
# # THANK YOU
